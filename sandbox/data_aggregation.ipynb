# %%
import pandas as pd
import numpy as np
from stats_can import StatsCan
import json

# %%
# bc = pd.read_csv('/home/austin/Desktop/nwhacks/BC/98-401-X2016070_English_CSV_data.csv')
# ab = pd.read_csv('/home/austin/Desktop/nwhacks/Alberta/98-401-X2016069_English_CSV_data.csv')
# on = pd.read_csv('/home/austin/Desktop/nwhacks/Ontario/98-401-X2016066_English_CSV_data.csv')
can = pd.read_csv('/home/austin/Downloads/98-401-X2016059_eng_CSV/98-401-X2016059_English_CSV_data.csv')

# %%
# test = pd.read_csv('/home/austin/Downloads/CensusProfile2016-ProfilRecensement2016-20200111084058.csv', encoding = 'unicode_escape')

# %%
van = bc[bc["GEO_NAME"] == "Vancouver"].reset_index()
van

# %%
ab

# %%
test

# %%
sc = StatsCan()
# df = sc.table_to_df("98-316-X2016001")
df

# %%
can

# %%
pc = pd.read_csv('/home/austin/Downloads/98-401-X2016048_eng_CSV(3)/98-401-X2016048_English_CSV_data.csv')
# Out:
# /home/austin/Desktop/nwhacks/ltn/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3051: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
labour_data = pc[pc['GEO_NAME'] == "Vancouver"].reset_index().iloc[1896:1918].reset_index()
labour_data
# Out:
#     level_0    index  CENSUS_YEAR  GEO_CODE (POR)  GEO_LEVEL   GEO_NAME  GNR  \
# 0      1896  1370319         2016             973          1  Vancouver  4.4
# 1      1897  1370320         2016             973          1  Vancouver  4.4
# 2      1898  1370321         2016             973          1  Vancouver  4.4
# 3      1899  1370322         2016             973          1  Vancouver  4.4
# 4      1900  1370323         2016             973          1  Vancouver  4.4
# 5      1901  1370324         2016             973          1  Vancouver  4.4
# 6      1902  1370325         2016             973          1  Vancouver  4.4
# 7      1903  1370326         2016             973          1  Vancouver  4.4
# 8      1904  1370327         2016             973          1  Vancouver  4.4
# 9      1905  1370328         2016             973          1  Vancouver  4.4
# 10     1906  1370329         2016             973          1  Vancouver  4.4
# 11     1907  1370330         2016             973          1  Vancouver  4.4
# 12     1908  1370331         2016             973          1  Vancouver  4.4
# 13     1909  1370332         2016             973          1  Vancouver  4.4
# 14     1910  1370333         2016             973          1  Vancouver  4.4
# 15     1911  1370334         2016             973          1  Vancouver  4.4
# 16     1912  1370335         2016             973          1  Vancouver  4.4
# 17     1913  1370336         2016             973          1  Vancouver  4.4
# 18     1914  1370337         2016             973          1  Vancouver  4.4
# 19     1915  1370338         2016             973          1  Vancouver  4.4
# 20     1916  1370339         2016             973          1  Vancouver  4.4
# 21     1917  1370340         2016             973          1  Vancouver  4.4
#
#     GNR_LF  DATA_QUALITY_FLAG  ALT_GEO_CODE  \
# 0      5.7                  1           973
# 1      5.7                  1           973
# 2      5.7                  1           973
# 3      5.7                  1           973
# 4      5.7                  1           973
# 5      5.7                  1           973
# 6      5.7                  1           973
# 7      5.7                  1           973
# 8      5.7                  1           973
# 9      5.7                  1           973
# 10     5.7                  1           973
# 11     5.7                  1           973
# 12     5.7                  1           973
# 13     5.7                  1           973
# 14     5.7                  1           973
# 15     5.7                  1           973
# 16     5.7                  1           973
# 17     5.7                  1           973
# 18     5.7                  1           973
# 19     5.7                  1           973
# 20     5.7                  1           973
# 21     5.7                  1           973
#
#             DIM: Profile of Population Centres (2247)  \
# 0   Total Labour Force population aged 15 years an...
# 1               Industry - NAICS2012 - not applicable
# 2                             All industry categories
# 3       11 Agriculture, forestry, fishing and hunting
# 4    21 Mining, quarrying, and oil and gas extraction
# 5                                        22 Utilities
# 6                                     23 Construction
# 7                                 31-33 Manufacturing
# 8                                  41 Wholesale trade
# 9                                  44-45 Retail trade
# 10               48-49 Transportation and warehousing
# 11             51 Information and cultural industries
# 12                           52 Finance and insurance
# 13              53 Real estate and rental and leasing
# 14  54 Professional, scientific and technical serv...
# 15         55 Management of companies and enterprises
# 16  56 Administrative and support, waste managemen...
# 17                            61 Educational services
# 18               62 Health care and social assistance
# 19              71 Arts, entertainment and recreation
# 20                 72 Accommodation and food services
# 21   81 Other services (except public administration)
#
#     Member ID: Profile of Population Centres (2247)  \
# 0                                              1897
# 1                                              1898
# 2                                              1899
# 3                                              1900
# 4                                              1901
# 5                                              1902
# 6                                              1903
# 7                                              1904
# 8                                              1905
# 9                                              1906
# 10                                             1907
# 11                                             1908
# 12                                             1909
# 13                                             1910
# 14                                             1911
# 15                                             1912
# 16                                             1913
# 17                                             1914
# 18                                             1915
# 19                                             1916
# 20                                             1917
# 21                                             1918
#
#     Notes: Profile of Population Centres (2247)  \
# 0                                         226.0
# 1                                         227.0
# 2                                         228.0
# 3                                           NaN
# 4                                           NaN
# 5                                           NaN
# 6                                           NaN
# 7                                           NaN
# 8                                           NaN
# 9                                           NaN
# 10                                          NaN
# 11                                          NaN
# 12                                          NaN
# 13                                          NaN
# 14                                          NaN
# 15                                          NaN
# 16                                          NaN
# 17                                          NaN
# 18                                          NaN
# 19                                          NaN
# 20                                          NaN
# 21                                          NaN
#
#    Dim: Sex (3): Member ID: [1]: Total - Sex  \
# 0                                1.25496e+06
# 1                                      23720
# 2                                1.23124e+06
# 3                                      10325
# 4                                       4045
# 5                                       6325
# 6                                      89035
# 7                                      78265
# 8                                      50820
# 9                                     139465
# 10                                     68470
# 11                                     47820
# 12                                     60870
# 13                                     32600
# 14                                    123930
# 15                                      2915
# 16                                     56980
# 17                                     92000
# 18                                    127730
# 19                                     28825
# 20                                    105250
# 21                                     56140
#
#    Dim: Sex (3): Member ID: [2]: Male Dim: Sex (3): Member ID: [3]: Female
# 0                              651180                               603790
# 1                               11055                                12670
# 2                              640125                               591125
# 3                                5340                                 4980
# 4                                2890                                 1150
# 5                                4060                                 2265
# 6                               77825                                11210
# 7                               52420                                25845
# 8                               33080                                17745
# 9                               65525                                73940
# 10                              53005                                15470
# 11                              30085                                17735
# 12                              26910                                33965
# 13                              17940                                14660
# 14                              69685                                54250
# 15                               1330                                 1585
# 16                              32965                                24005
# 17                              31715                                60285
# 18                              26480                               101255
# 19                              14610                                14210
# 20                              46385                                58865
# 21                              23020                                33120

# %%
labour_data[""]
# Out:
# CENSUS_YEAR                                                                         2016
# GEO_CODE (POR)                                                                         1
# GEO_LEVEL                                                                              1
# GEO_NAME                                                                           Acton
# GNR                                                                                  2.2
# GNR_LF                                                                               5.3
# DATA_QUALITY_FLAG                                                                      0
# ALT_GEO_CODE                                                                           1
# DIM: Profile of Population Centres (2247)          Industry - NAICS2012 - not applicable
# Member ID: Profile of Population Centres (2247)                                     1898
# Notes: Profile of Population Centres (2247)                                          227
# Dim: Sex (3): Member ID: [1]: Total - Sex                                             70
# Dim: Sex (3): Member ID: [2]: Male                                                    30
# Dim: Sex (3): Member ID: [3]: Female                                                  35
# Name: 1897, dtype: object

# %%
def get_pc_attribute(df, city, idxs, attrib_name):
        """ Returns the df of a specific attribute a Population Centre"""
        attrib_data = df[df['GEO_NAME'] == city].reset_index().iloc[idxs[0]:idxs[1]].reset_index()
        new_df = pd.DataFrame()
        new_df[attrib_name] = attrib_data["DIM: Profile of Population Centres (2247)"]
        new_df["count"] = attrib_data["Dim: Sex (3): Member ID: [1]: Total - Sex"]
        new_df[attrib_name + "_rate"] = new_df[attrib_name + "_count"]/new_df[attrib_name + "_count"].sum()
        return new_df
    
def trim_labour_data(labour_df, col_name):
        labour_df[col_name] = labour_df[col_name].str.extract(r'.*? (.*)')
        return labour_df

tor = get_pc_attribute(pc, "Toronto", (1899, 1919), "labour_category")
tor_trim = trim_labour_data(tor, "labour_category")

tor_trim.to_dict('records')
# Out:
# [{'labour_category': 'Agriculture, forestry, fishing and hunting',
#   'labour_category_count': 5115.0,
#   'labour_category_rate': 0.0017832023385574364},
#  {'labour_category': 'Mining, quarrying, and oil and gas extraction',
#   'labour_category_count': 3950.0,
#   'labour_category_rate': 0.0013770575243991932},
#  {'labour_category': 'Utilities',
#   'labour_category_count': 13965.0,
#   'labour_category_rate': 0.004868508437527781},
#  {'labour_category': 'Construction',
#   'labour_category_count': 163810.0,
#   'labour_category_rate': 0.05710779571438781},
#  {'labour_category': 'Manufacturing',
#   'labour_category_count': 256170.0,
#   'labour_category_rate': 0.08930653823426363},
#  {'labour_category': 'Wholesale trade',
#   'labour_category_count': 128255.0,
#   'labour_category_rate': 0.044712534884004694},
#  {'labour_category': 'Retail trade',
#   'labour_category_count': 307460.0,
#   'labour_category_rate': 0.1071873687219686},
#  {'labour_category': 'Transportation and warehousing',
#   'labour_category_count': 153930.0,
#   'labour_category_rate': 0.05366340879259945},
#  {'labour_category': 'Information and cultural industries',
#   'labour_category_count': 100825.0,
#   'labour_category_rate': 0.035149829087987},
#  {'labour_category': 'Finance and insurance',
#   'labour_category_count': 233060.0,
#   'labour_category_rate': 0.08124988016113316},
#  {'labour_category': 'Real estate and rental and leasing',
#   'labour_category_count': 76725.0,
#   'labour_category_rate': 0.026748035078361546},
#  {'labour_category': 'Professional, scientific and technical services',
#   'labour_category_count': 317960.0,
#   'labour_category_rate': 0.11084790138176392},
#  {'labour_category': 'Management of companies and enterprises',
#   'labour_category_count': 7965.0,
#   'labour_category_rate': 0.00277677548907331},
#  {'labour_category': 'Administrative and support, waste management and remediation services',
#   'labour_category_count': 148930.0,
#   'labour_category_rate': 0.05192029800222072},
#  {'labour_category': 'Educational services',
#   'labour_category_count': 208170.0,
#   'labour_category_rate': 0.07257267464662787},
#  {'labour_category': 'Health care and social assistance',
#   'labour_category_count': 265290.0,
#   'labour_category_rate': 0.09248597231591443},
#  {'labour_category': 'Arts, entertainment and recreation',
#   'labour_category_count': 57575.0,
#   'labour_category_rate': 0.020071920751211027},
#  {'labour_category': 'Accommodation and food services',
#   'labour_category_count': 189685.0,
#   'labour_category_rate': 0.06612839405459772},
#  {'labour_category': 'Other services (except public administration)',
#   'labour_category_count': 123585.0,
#   'labour_category_rate': 0.043084469405790964},
#  {'labour_category': 'Public administration',
#   'labour_category_count': 106010.0,
#   'labour_category_rate': 0.03695743497760974}]

# %%
tor['rate'] = tor['count']/tor['count'].sum()

# %%
tor.sum()
# Out:
# labour_category    11 Agriculture, forestry, fishing and hunting2...
# count                                                    2.86844e+06
# rate                                                               1
# dtype: object

# %%
tor["new_lab"] = tor["labour_category"].str.extract(r'.*? (.*)')

# %%
tor
# Out:
#                                       labour_category   count        rate  \
# 0       11 Agriculture, forestry, fishing and hunting    5115   0.0017832
# 1    21 Mining, quarrying, and oil and gas extraction    3950  0.00137706
# 2                                        22 Utilities   13965  0.00486851
# 3                                     23 Construction  163810   0.0571078
# 4                                 31-33 Manufacturing  256170   0.0893065
# 5                                  41 Wholesale trade  128255   0.0447125
# 6                                  44-45 Retail trade  307460    0.107187
# 7                48-49 Transportation and warehousing  153930   0.0536634
# 8              51 Information and cultural industries  100825   0.0351498
# 9                            52 Finance and insurance  233060   0.0812499
# 10              53 Real estate and rental and leasing   76725    0.026748
# 11  54 Professional, scientific and technical serv...  317960    0.110848
# 12         55 Management of companies and enterprises    7965  0.00277678
# 13  56 Administrative and support, waste managemen...  148930   0.0519203
# 14                            61 Educational services  208170   0.0725727
# 15               62 Health care and social assistance  265290    0.092486
# 16              71 Arts, entertainment and recreation   57575   0.0200719
# 17                 72 Accommodation and food services  189685   0.0661284
# 18   81 Other services (except public administration)  123585   0.0430845
# 19                           91 Public administration  106010   0.0369574
#
#                                               new_lab
# 0          Agriculture, forestry, fishing and hunting
# 1       Mining, quarrying, and oil and gas extraction
# 2                                           Utilities
# 3                                        Construction
# 4                                       Manufacturing
# 5                                     Wholesale trade
# 6                                        Retail trade
# 7                      Transportation and warehousing
# 8                 Information and cultural industries
# 9                               Finance and insurance
# 10                 Real estate and rental and leasing
# 11    Professional, scientific and technical services
# 12            Management of companies and enterprises
# 13  Administrative and support, waste management a...
# 14                               Educational services
# 15                  Health care and social assistance
# 16                 Arts, entertainment and recreation
# 17                    Accommodation and food services
# 18      Other services (except public administration)
# 19                              Public administration

# %%
# making base json file
base = {}
base['labour'] = {}
base['commute_time'] = {}
base['commute_mode'] = {}
base['cost_living'] = {}
base['']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-96-02074519b602> in <module>
#       5 base['commute_mode'] = {}
#       6 base['cost_living'] = {}
# ----> 7 base['']
#
# KeyError: ''

# %%
json.dump(base, open(r'base.json','w'))

# %%
tor.set_index('labour_category')

dict(zip(tor['new_lab'], tor['count'], tor['rate']))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-106-6a37d7a74ef3> in <module>
#       1 tor.set_index('labour_category')
#       2
# ----> 3 dict(zip(tor['new_lab'], tor['count'], tor['rate']))
#
# ValueError: dictionary update sequence element #0 has length 3; 2 is required

# %%
dict(zip('count', tor['count']))
tor.to_dict('records')
# Out:
# [{'labour_category': '11 Agriculture, forestry, fishing and hunting',
#   'count': 5115.0,
#   'rate': 0.0017832023385574364,
#   'new_lab': 'Agriculture, forestry, fishing and hunting'},
#  {'labour_category': '21 Mining, quarrying, and oil and gas extraction',
#   'count': 3950.0,
#   'rate': 0.0013770575243991932,
#   'new_lab': 'Mining, quarrying, and oil and gas extraction'},
#  {'labour_category': '22 Utilities',
#   'count': 13965.0,
#   'rate': 0.004868508437527781,
#   'new_lab': 'Utilities'},
#  {'labour_category': '23 Construction',
#   'count': 163810.0,
#   'rate': 0.05710779571438781,
#   'new_lab': 'Construction'},
#  {'labour_category': '31-33 Manufacturing',
#   'count': 256170.0,
#   'rate': 0.08930653823426363,
#   'new_lab': 'Manufacturing'},
#  {'labour_category': '41 Wholesale trade',
#   'count': 128255.0,
#   'rate': 0.044712534884004694,
#   'new_lab': 'Wholesale trade'},
#  {'labour_category': '44-45 Retail trade',
#   'count': 307460.0,
#   'rate': 0.1071873687219686,
#   'new_lab': 'Retail trade'},
#  {'labour_category': '48-49 Transportation and warehousing',
#   'count': 153930.0,
#   'rate': 0.05366340879259945,
#   'new_lab': 'Transportation and warehousing'},
#  {'labour_category': '51 Information and cultural industries',
#   'count': 100825.0,
#   'rate': 0.035149829087987,
#   'new_lab': 'Information and cultural industries'},
#  {'labour_category': '52 Finance and insurance',
#   'count': 233060.0,
#   'rate': 0.08124988016113316,
#   'new_lab': 'Finance and insurance'},
#  {'labour_category': '53 Real estate and rental and leasing',
#   'count': 76725.0,
#   'rate': 0.026748035078361546,
#   'new_lab': 'Real estate and rental and leasing'},
#  {'labour_category': '54 Professional, scientific and technical services',
#   'count': 317960.0,
#   'rate': 0.11084790138176392,
#   'new_lab': 'Professional, scientific and technical services'},
#  {'labour_category': '55 Management of companies and enterprises',
#   'count': 7965.0,
#   'rate': 0.00277677548907331,
#   'new_lab': 'Management of companies and enterprises'},
#  {'labour_category': '56 Administrative and support, waste management and remediation services',
#   'count': 148930.0,
#   'rate': 0.05192029800222072,
#   'new_lab': 'Administrative and support, waste management and remediation services'},
#  {'labour_category': '61 Educational services',
#   'count': 208170.0,
#   'rate': 0.07257267464662787,
#   'new_lab': 'Educational services'},
#  {'labour_category': '62 Health care and social assistance',
#   'count': 265290.0,
#   'rate': 0.09248597231591443,
#   'new_lab': 'Health care and social assistance'},
#  {'labour_category': '71 Arts, entertainment and recreation',
#   'count': 57575.0,
#   'rate': 0.020071920751211027,
#   'new_lab': 'Arts, entertainment and recreation'},
#  {'labour_category': '72 Accommodation and food services',
#   'count': 189685.0,
#   'rate': 0.06612839405459772,
#   'new_lab': 'Accommodation and food services'},
#  {'labour_category': '81 Other services (except public administration)',
#   'count': 123585.0,
#   'rate': 0.043084469405790964,
#   'new_lab': 'Other services (except public administration)'},
#  {'labour_category': '91 Public administration',
#   'count': 106010.0,
#   'rate': 0.03695743497760974,
#   'new_lab': 'Public administration'}]
